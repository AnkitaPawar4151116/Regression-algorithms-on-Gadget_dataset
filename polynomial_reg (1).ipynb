# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings('ignore')

# %%
ds= pd.read_csv('tech_gadgets_rating_dataset.csv')
ds
# Out:
#      Price  Battery_Life  RAM_GB    Brand  Rating
# 0    31961            15       6   Others     3.5
# 1    54033            22      12  Samsung     4.4
# 2    25867            16       6   Others     3.8
# 3    45668            23       6  OnePlus     4.1
# 4    66524            23      12  OnePlus     4.5
# 5    49594            21       8  Samsung     4.6
# 6    62599            21       6  Samsung     4.5
# 7    30480            21       8  OnePlus     4.1
# 8    26191            13       6   Others     3.7
# 9    65713            21       8  Samsung     4.5
# 10   73071            23       8    Apple     4.6
# 11   50182            20       6  Samsung     4.3
# 12   16590            20       6   Others     3.7
# 13   49099            21      12  Samsung     4.3
# 14   30610            18       6  OnePlus     4.3
# 15   65323            21       8  Samsung     4.3
# 16   37756            20       6  OnePlus     4.4
# 17   22192            14       6   Others     4.0
# 18   39345            17       6   Others     3.9
# 19   30647            21      12  OnePlus     4.1
# 20   20378            14       6   Others     3.6
# 21   85341            24      32    Apple     4.7
# 22   46310            23      12  Samsung     4.5
# 23   87628            24      12  Samsung     4.1
# 24   41580            21       8  OnePlus     4.1
# 25   74823            24       8    Apple     4.5
# 26   51390            20       6  OnePlus     4.1
# 27   86696            24       8  Samsung     4.4
# 28  112918            20      32    Apple     4.8
# 29   23886            18       8   Others     4.1
# 30   59022            18       8  OnePlus     4.0
# 31  104801            24      16    Apple     4.8
# 32   75939            23       8  Samsung     4.2
# 33   54275            20       8  OnePlus     4.2
# 34   73370            20      16    Apple     4.9
# 35   26072            17       6   Others     4.0
# 36   50004            22      12  OnePlus     4.4
# 37   47460            22       8  Samsung     4.5
# 38   31299            20      12  OnePlus     4.3
# 39   42570            24      12  Samsung     4.6
# 40   52352            20       8  Samsung     4.4
# 41   99673            19      32    Apple     4.4
# 42   61752            20       6  Samsung     4.5
# 43   42792            21       8  OnePlus     4.5
# 44   25011            13       4   Others     4.2
# 45   21240            20       6   Others     3.8
# 46   23745            13       6   Others     4.0
# 47   17839            12       4   Others     3.7
# 48   20764            14       6   Others     3.8
# 49   57979            18       6  OnePlus     4.1

# %%
x=ds[['Price']]
y=ds[['Rating']]

# %%
plt.scatter(x,y)
plt.show()

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.2,random_state=1)

# %%
from sklearn.preprocessing import PolynomialFeatures
pf = PolynomialFeatures(degree=3)
pf.fit_transform(x_train)
# Out:
# array([[1.00000000e+00, 7.59390000e+04, 5.76673172e+09, 4.37919840e+14],
#        [1.00000000e+00, 4.25700000e+04, 1.81220490e+09, 7.71455626e+13],
#        [1.00000000e+00, 8.53410000e+04, 7.28308628e+09, 6.21545866e+14],
#        [1.00000000e+00, 5.00040000e+04, 2.50040002e+09, 1.25030002e+14],
#        [1.00000000e+00, 3.06470000e+04, 9.39238609e+08, 2.87848457e+13],
#        [1.00000000e+00, 6.17520000e+04, 3.81330950e+09, 2.35479488e+14],
#        [1.00000000e+00, 5.79790000e+04, 3.36156444e+09, 1.94900145e+14],
#        [1.00000000e+00, 5.13900000e+04, 2.64093210e+09, 1.35717501e+14],
#        [1.00000000e+00, 4.63100000e+04, 2.14461610e+09, 9.93171716e+13],
#        [1.00000000e+00, 4.90990000e+04, 2.41071180e+09, 1.18363539e+14],
#        [1.00000000e+00, 9.96730000e+04, 9.93470693e+09, 9.90222044e+14],
#        [1.00000000e+00, 2.21920000e+04, 4.92484864e+08, 1.09292241e+13],
#        [1.00000000e+00, 2.12400000e+04, 4.51137600e+08, 9.58216262e+12],
#        [1.00000000e+00, 4.15800000e+04, 1.72889640e+09, 7.18875123e+13],
#        [1.00000000e+00, 8.76280000e+04, 7.67866638e+09, 6.72866178e+14],
#        [1.00000000e+00, 6.65240000e+04, 4.42544258e+09, 2.94398142e+14],
#        [1.00000000e+00, 5.42750000e+04, 2.94577562e+09, 1.59881972e+14],
#        [1.00000000e+00, 3.06100000e+04, 9.36972100e+08, 2.86807160e+13],
#        [1.00000000e+00, 5.90220000e+04, 3.48359648e+09, 2.05608832e+14],
#        [1.00000000e+00, 7.30710000e+04, 5.33937104e+09, 3.90153181e+14],
#        [1.00000000e+00, 1.12918000e+05, 1.27504747e+10, 1.43975810e+15],
#        [1.00000000e+00, 2.50110000e+04, 6.25550121e+08, 1.56456341e+13],
#        [1.00000000e+00, 7.33700000e+04, 5.38315690e+09, 3.94962222e+14],
#        [1.00000000e+00, 3.93450000e+04, 1.54802902e+09, 6.09072020e+13],
#        [1.00000000e+00, 2.03780000e+04, 4.15262884e+08, 8.46222705e+12],
#        [1.00000000e+00, 7.48230000e+04, 5.59848133e+09, 4.18895168e+14],
#        [1.00000000e+00, 6.25990000e+04, 3.91863480e+09, 2.45302620e+14],
#        [1.00000000e+00, 3.04800000e+04, 9.29030400e+08, 2.83168466e+13],
#        [1.00000000e+00, 1.78390000e+04, 3.18229921e+08, 5.67690356e+12],
#        [1.00000000e+00, 5.40330000e+04, 2.91956509e+09, 1.57752860e+14],
#        [1.00000000e+00, 3.77560000e+04, 1.42551554e+09, 5.38217646e+13],
#        [1.00000000e+00, 3.19610000e+04, 1.02150552e+09, 3.26483380e+13],
#        [1.00000000e+00, 6.53230000e+04, 4.26709433e+09, 2.78739403e+14],
#        [1.00000000e+00, 4.95940000e+04, 2.45956484e+09, 1.21979658e+14],
#        [1.00000000e+00, 5.01820000e+04, 2.51823312e+09, 1.26369975e+14],
#        [1.00000000e+00, 6.57130000e+04, 4.31819837e+09, 2.83761769e+14],
#        [1.00000000e+00, 2.61910000e+04, 6.85968481e+08, 1.79662005e+13],
#        [1.00000000e+00, 1.65900000e+04, 2.75228100e+08, 4.56603418e+12],
#        [1.00000000e+00, 4.27920000e+04, 1.83115526e+09, 7.83587961e+13],
#        [1.00000000e+00, 4.74600000e+04, 2.25245160e+09, 1.06901353e+14]])

# %%
from sklearn.linear_model import LinearRegression
reg= LinearRegression()
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred= reg.predict(x_test)
y_pred
# Out:
# array([[4.59503891],
#        [4.00868987],
#        [4.26286731],
#        [4.05924487],
#        [4.00670713],
#        [4.19822035],
#        [3.95735144],
#        [3.9875471 ],
#        [3.98618337],
#        [4.7701486 ]])

# %%
from sklearn.metrics import r2_score
score = r2_score(y_test,y_pred)
score
# Out:
# 0.7610379664710986
