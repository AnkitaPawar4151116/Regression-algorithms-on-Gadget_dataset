# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings('ignore')

# %%
ds= pd.read_csv('tech_gadgets_rating_dataset.csv')
ds
# Out:
#      Price  Battery_Life  RAM_GB    Brand  Rating
# 0    31961            15       6   Others     3.5
# 1    54033            22      12  Samsung     4.4
# 2    25867            16       6   Others     3.8
# 3    45668            23       6  OnePlus     4.1
# 4    66524            23      12  OnePlus     4.5
# 5    49594            21       8  Samsung     4.6
# 6    62599            21       6  Samsung     4.5
# 7    30480            21       8  OnePlus     4.1
# 8    26191            13       6   Others     3.7
# 9    65713            21       8  Samsung     4.5
# 10   73071            23       8    Apple     4.6
# 11   50182            20       6  Samsung     4.3
# 12   16590            20       6   Others     3.7
# 13   49099            21      12  Samsung     4.3
# 14   30610            18       6  OnePlus     4.3
# 15   65323            21       8  Samsung     4.3
# 16   37756            20       6  OnePlus     4.4
# 17   22192            14       6   Others     4.0
# ...

# %%
x=ds[['Price', 'Battery_Life', 'RAM_GB', 'Brand']]
y=ds[['Rating']]

# %%
from sklearn.preprocessing import OneHotEncoder
ohe= OneHotEncoder(sparse_output=False)
endata= ohe.fit_transform(x[['Brand']])
endata

column_name=ohe.get_feature_names_out(['Brand'])
endf= pd.DataFrame(endata , columns=column_name)
endf

x= pd.concat([x,endf], axis=1)

x= x.drop(columns=['Brand'])
x
# Out:
#      Price  Battery_Life  RAM_GB  Brand_Apple  Brand_OnePlus  Brand_Others  \
# 0    31961            15       6          0.0            0.0           1.0
# 1    54033            22      12          0.0            0.0           0.0
# 2    25867            16       6          0.0            0.0           1.0
# 3    45668            23       6          0.0            1.0           0.0
# 4    66524            23      12          0.0            1.0           0.0
# 5    49594            21       8          0.0            0.0           0.0
# 6    62599            21       6          0.0            0.0           0.0
# 7    30480            21       8          0.0            1.0           0.0
# 8    26191            13       6          0.0            0.0           1.0
# 9    65713            21       8          0.0            0.0           0.0
# 10   73071            23       8          1.0            0.0           0.0
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.2,random_state=1)

# %%
from sklearn.ensemble import RandomForestRegressor
reg= RandomForestRegressor(n_estimators=10, random_state=1)
reg.fit(x_train,y_train)
# Out:
# RandomForestRegressor(n_estimators=10, random_state=1)

# %%
from sklearn.tree import plot_tree
plot_tree(reg.estimators_[0], filled=True)
plt.title('Random Forest Visualization')
plt.show()

# %%
y_pred= reg.predict(x_test)
y_pred
# Out:
# array([4.31, 3.81, 4.38, 4.2 , 3.74, 4.48, 3.7 , 3.95, 3.93, 4.52])

# %%
y_test
# Out:
#     Rating
# 27     4.4
# 35     4.0
# 40     4.4
# 38     4.3
# 2      3.8
# 3      4.1
# 48     3.8
# 29     4.1
# 46     4.0
# 31     4.8
